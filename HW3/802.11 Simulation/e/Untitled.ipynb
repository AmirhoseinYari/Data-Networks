# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
n = np.arange(1,16,1)
thro_dis = np.array([3.06, 2.96, 2.34, 2.01, 1.73, 1.54, 1.24, 1.11, 1.02, .89, .81, .79, .7, .69, .59])
thro_enb = np.array([3.06, 2.34, 1.89, 1.58, 1.34, 1.16, .99, .9, .83, .74, .67, .62, .56, .55, .51])
plt.figure(figsize=(12,8))
plt.plot(n,thro_dis, n,thro_enb)
plt.legend(["RTS/CTS disabled", "RTS/CTS enabled"]);
plt.xlabel("n")
plt.ylabel("Throughput");
plt.title("Throughput vs n :");
